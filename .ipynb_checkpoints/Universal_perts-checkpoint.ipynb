# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
from models import model, eval
import torch
from utils import dev, orth_check
from torchvision import datasets, transforms
from sklearn import decomposition
from tqdm import tqdm
import subspace_utils
from sklearn.decomposition import PCA

# %matplotlib inline

# %% [markdown]
# # Universal Advs

# %%
# define functions

def get_dist(orig, pert, model, delta=0.01, epsilons = np.linspace(-100,100,201)):
    orig = orig.reshape(784)
    unitary_pert = pert.reshape(784)/np.linalg.norm(pert.reshape(784))
    
    label = np.argmax(model(torch.tensor(np.reshape(orig, (1, 1, 28, 28)), device=dev())).detach().cpu().numpy())
    
    inputs = np.outer(epsilons,unitary_pert) + orig
    
    pred = model(torch.tensor(inputs.astype('float32'), device=dev()).reshape(-1, 1, 28, 28)).detach().cpu().numpy()
    pred_classes = np.argmax(pred, axis=-1)

    if np.all(pred_classes==label):
        return np.nan
    
    changed = epsilons[pred_classes != label]
    min_epsilon_idx = np.argmin(abs(changed))
    idx = np.argwhere(epsilons==changed[min_epsilon_idx])

    
    # do a second search with more precise epsilon
    if epsilons[idx]>0:
        new_epsilons = np.linspace(epsilons[idx-1], epsilons[idx], np.maximum(int(1/delta),100))
    else: 
        new_epsilons = np.linspace(epsilons[idx+1], epsilons[idx], np.maximum(int(1/delta),100))
        
    inputs = np.outer(new_epsilons, unitary_pert) + orig
    
    pred = model(torch.tensor(inputs.astype('float32'), device=dev()).reshape(-1, 1, 28, 28)).detach().cpu().numpy()
    pred_classes = np.argmax(pred, axis=-1)
    
    idx = np.min(np.argwhere(pred_classes != label))
        
    return np.linalg.norm(proj_inputs[idx]-orig)
    

def get_mean_dist(orig, model, n_sample_dirs=100, delta=0.01):
    dists = np.zeros(n_sample_dirs)
        
    # generate n random unitary vectors
    dirs = np.random.uniform(size=(n_sample_dirs,784)) - orig.reshape(784)
    
    for i, d in enumerate(dirs):
        dists[i] = get_dist(orig, d, model, delta, epsilons = np.linspace(0,100,101))
        
    mean_dist = np.nanmean(dists)
    
    return mean_dist

# %% [markdown]
# ## Load data and models

# %%
# load data
data = np.load('data/cnn5.npy', allow_pickle=True).item()
advs = data['advs']
pert_lengths = data['pert_lengths']
classes = data['adv_class']
dirs = data['dirs']
images = data['images']
labels = data['labels']
pert_lengths = data['pert_lengths']

# %%
# load models
model_natural = model.madry()
model_madry = model.madry()
model_natural.load_state_dict(torch.load('./models/natural.pt', map_location=torch.device(dev())))
model_madry.load_state_dict(torch.load('./models/adv_trained_l2.pt', map_location=torch.device(dev())))
model_natural.to(dev())
model_madry.to(dev())
# Out:
# madry(
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (maxPool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (maxPool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=3136, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=10, bias=True)
#   (relu): ReLU()
# )

# %%
# extract singular values and vectors
M = (dirs[:,0]-np.mean(dirs[:,0],axis=-1).reshape(-1,1)).reshape(-1,dirs[:,0].shape[-1])
u,s,v = np.linalg.svd(M)

# visualize first 10 singular vectors
plt.subplots(2,5,figsize=(15,5))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(v[i].reshape((28,28)))
    plt.xticks([])
    plt.yticks([])
    plt.title('SV' + str(i+1))
plt.suptitle('SVs', fontsize= 'xx-large')
    
# extract
pca = PCA()
pca.fit(M)

# visualize first 10 singular vectors
plt.subplots(2,5,figsize=(15,5))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(pca.components_[i].reshape((28,28)))
    plt.xticks([])
    plt.yticks([])
    plt.title('PC' + str(i+1))
plt.suptitle('PCs', fontsize= 'xx-large')
plt.show()

# %% [markdown]
# ## Check how many random perturbation samples are needed for good estimate

# %%
# # see when random length converges
# n_runs = 100
# n_samples = np.linspace(10,20000,n_runs)
# e_random = np.zeros(n_runs)
# for i,n in enumerate(tqdm(n_samples)):
# #     print('Estimating distance to decision boundary with %d random directions.' % (n))
#     e_random[i] = get_mean_dist(images[1], model_natural, int(n))
plt.plot(n_samples,e_random)
plt.xlabel('n smamples')
plt.ylabel('l2 distance')
plt.title('mean distance to decision boundary of random direction for different sample rates')
# Out:
# Text(0.5, 1.0, 'mean distance to decision boundary of random direction for different sample rates')

# %% [markdown]
# ## Get distances for random directions on random images

# %%
n_images = 100
img_indices = np.arange(len(images))
np.random.shuffle(img_indices)
img_indices=img_indices[:n_images]
d_random= np.zeros(n_images)

for i, img in enumerate(tqdm(images[img_indices])):
    d_random[i] = get_mean_dist(img, model_natural, n_sample_dirs=500)
print('Mean length of random direction needed to reach decision boundary: %.2f' % (np.nanmean(d_random)))
# Out:
# 100%|██████████| 100/100 [02:38<00:00,  1.59s/it]
# Mean length of random direction needed to reach decision boundary: 10.41

# %% [markdown]
# ## Get ratios for singular vectors

# %%
n_singular_vectors = len(images)
d_svd = np.zeros((n_images, n_singular_vectors))

for i, img in enumerate(tqdm(images[img_indices])):
    for j in range(n_singular_vectors):
        d_svd[i,j] = get_dist(img, v[j], model_natural)
# Out:
# 100%|██████████| 100/100 [03:09<00:00,  1.90s/it]

# %%
ratios_svd = np.nanmean(d_svd /d_random.reshape(-1,1),axis=0)
plt.figure(figsize=(8,5))
plt.scatter(np.arange(1,len(ratios_svd)+1),ratios_svd,s=3)
plt.xlabel('n-th singular vector')
plt.ylabel('l2 distance ratio')
plt.title('Ratio of singular vector and random direction l2 distance to decsion boundary')
# Out:
# Text(0.5, 1.0, 'Ratio of singular vector and random direction l2 distance to decsion boundary')

# %% [markdown]
# ## Get ratios for principal components

# %%
n_pincipal_components = len(images)
d_pca = np.zeros((n_images, n_pincipal_components))

for i, img in enumerate(tqdm(images[img_indices])):
    for j in range(n_pincipal_components):
        d_pca[i,j] = get_dist(img, pca.components_[j], model_natural)
# Out:
# 100%|██████████| 100/100 [03:13<00:00,  1.93s/it]

# %%
ratios_pca = np.nanmean(d_pca /d_random.reshape(-1,1),axis=0)
plt.figure(figsize=(8,5))
plt.scatter(np.arange(1,len(ratios_pca)+1),ratios_pca,s=3)
plt.xlabel('n-th principal component')
plt.ylabel('l2 distance ratio')
plt.title('Ratio of principal component and random direction l2 distance to decsion boundary')
# Out:
# Text(0.5, 1.0, 'Ratio of principal component and random direction l2 distance to decsion boundary')

# %% [markdown]
# ## Get ratios of random perturbations and principal adversarial directions

# %%
# ratio of principle adversarials
d_adv=np.zeros((n_images,5))

for i, idx in enumerate(img_indices):
    for j,d in enumerate(dirs[idx]):
        d_adv[i,j] = get_dist(images[idx], dirs[idx,j], model_natural)

# %%
ratios_adv = np.nanmean(d_adv /d_random.reshape(-1,1),axis=0)
plt.figure(figsize=(8,5))
plt.plot(np.arange(1,d_adv.shape[1]+1),ratios_adv)
plt.xlabel('n-th principal adversarial direction')
plt.ylabel('l2 distance ratio')
# plt.xticks(np.arange(1,d_svd.shape[1]+1,d_svd.shape[1]/10))
plt.title('Ratio of random and principal adversarial direction l2 distance to decsion boundary')
# Out:
# Text(0.5, 1.0, 'Ratio of random and principal adversarial direction l2 distance to decsion boundary')

# %% [markdown]
# ## Extract universal perturbations via code from https://paperswithcode.com/paper/universal-adversarial-perturbations

# %%
from UniversalPerturbations import adversarial_perturbation

trainset = torch.utils.data.DataLoader(
    datasets.MNIST('./data', train=True, download=True,
                   transform=transforms.ToTensor()),
    batch_size=128, shuffle=True)

testset = torch.utils.data.DataLoader(
    datasets.MNIST('./data', train=False,
                   transform=transforms.ToTensor()),
    batch_size=128)

net = model_natural

# universal_pert, fooling_rates, accuracies, total_iterations = adversarial_perturbation.generate(trainset, testset, net,delta=0.1, p=2, xi=5, max_iter_uni=30)

# plt.title("Fooling Rates over Universal Iterations")
# plt.xlabel("Universal Algorithm Iter")
# plt.ylabel("Fooling Rate on test data")
# plt.plot(np.arange(total_iterations+1),fooling_rates)
# plt.show()


# plt.title("Accuracy over Universal Iterations")
# plt.xlabel("Universal Algorithm Iter")
# plt.ylabel("Accuracy on Test data")
# plt.plot(np.arange(total_iterations+1), accuracies)
# plt.show()

# plt.imshow(universal_pert)
# plt.colorbar()
# plt.show()

# %%
n_svds = 50
l2_norms = np.arange(1,12,0.5)
fooling_rates_universal = np.zeros(len(l2_norms))
fooling_rates_svd = np.zeros((n_svds,len(l2_norms)))
universal_perts = np.zeros((len(l2_norms),28,28))

for i, norm in enumerate(l2_norms):
    for j in range(3):
        universal_pert, fooling_rates, accuracies, total_iterations=adversarial_perturbation.generate(trainset, testset, net, delta=0.1, p=2, xi=norm, max_iter_uni=30)
        universal_perts[i] = universal_pert

        proj_inputs = np.clip(images + universal_pert, 0, 1)
        pred = model_natural(torch.tensor(proj_inputs.astype('float32'), device=dev()).reshape(-1, 1, 28, 28)).detach().cpu().numpy()
        new_labels = np.argmax(pred, axis=-1)

        fooling_rates_universal[i] += (new_labels != labels).sum()/len(labels)
    fooling_rates_universal[i]/=3
    for j in range(n_svds):
        proj_inputs = np.clip(images + norm*v[j].reshape((28,28)), 0, 1)
        pred = model_natural(torch.tensor(proj_inputs.astype('float32'), device=dev()).reshape(-1, 1, 28, 28)).detach().cpu().numpy()
        new_labels = np.argmax(pred, axis=-1)
        fooling_rates_svd[j,i] = (new_labels != labels).sum()/len(labels)      
    

cmap = plt.get_cmap('RdYlGn') 
fig = plt.figure(figsize=(9,5.5))
# plt.plot(l2_norms,fooling_rates_universal,'k--', linewidth=3)
for i, fr in enumerate(fooling_rates_svd):
    relative_ratio = (ratios_svd[i]-ratios_svd[:n_svds].min())/(ratios_svd[:n_svds].max()-ratios_svd[:n_svds].min())
    color = np.clip(relative_ratio,0,0.999)
    plt.plot(l2_norms, fr, c=cmap(1-relative_ratio))
plt.xlabel('l2-length of perturbation')
plt.ylabel('fooling rate')
sm = plt.cm.ScalarMappable(cmap=cmap)
cbar=plt.colorbar(sm, format='%.2f', label='ratio of dist. to dec. boundary compared to random dir.', boundaries=np.linspace(ratios_svd.min(),ratios_svd.max(),30), values=np.linspace(ratios_svd.max(),ratios_svd.min(),29))
# Out:
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.0024
# Iteration   2
#
# FOOLING RATE:  0.0022
# Iteration   3
#
# FOOLING RATE:  0.0021
# Iteration   4
#
# FOOLING RATE:  0.0022
# Iteration   5
#
# FOOLING RATE:  0.0023
# Iteration   6
#
# FOOLING RATE:  0.0021
# Iteration   7
#
# FOOLING RATE:  0.0022
# Iteration   8
#
# FOOLING RATE:  0.0022
# Iteration   9
#
# FOOLING RATE:  0.0024
# Iteration   10
#
# FOOLING RATE:  0.0022
# Iteration   11
#
# FOOLING RATE:  0.002
# Iteration   12
#
# FOOLING RATE:  0.0021
# Iteration   13
#
# FOOLING RATE:  0.0021
# Iteration   14
#
# FOOLING RATE:  0.0023
# Iteration   15
#
# FOOLING RATE:  0.0022
# Iteration   16
#
# FOOLING RATE:  0.0022
# Iteration   17
#
# FOOLING RATE:  0.0022
# Iteration   18
#
# FOOLING RATE:  0.0022
# Iteration   19
#
# FOOLING RATE:  0.0022
# Iteration   20
#
# FOOLING RATE:  0.0024
# Iteration   21
#
# FOOLING RATE:  0.0022
# Iteration   22
#
# FOOLING RATE:  0.0022
# Iteration   23
#
# FOOLING RATE:  0.0022
# Iteration   24
#
# FOOLING RATE:  0.0022
# Iteration   25
#
# FOOLING RATE:  0.0021
# Iteration   26
#
# FOOLING RATE:  0.0022
# Iteration   27
#
# FOOLING RATE:  0.0022
# Iteration   28
#
# FOOLING RATE:  0.0021
# Iteration   29
#
# FOOLING RATE:  0.0022
# Iteration   30
#
# FOOLING RATE:  0.0023
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.0013
# Iteration   2
#
# FOOLING RATE:  0.0011
# Iteration   3
#
# FOOLING RATE:  0.001
# Iteration   4
#
# FOOLING RATE:  0.0011
# Iteration   5
#
# FOOLING RATE:  0.0013
# Iteration   6
#
# FOOLING RATE:  0.0015
# Iteration   7
#
# FOOLING RATE:  0.0016
# Iteration   8
#
# FOOLING RATE:  0.0013
# Iteration   9
#
# FOOLING RATE:  0.0014
# Iteration   10
#
# FOOLING RATE:  0.0014
# Iteration   11
#
# FOOLING RATE:  0.0015
# Iteration   12
#
# FOOLING RATE:  0.0014
# Iteration   13
#
# FOOLING RATE:  0.0012
# Iteration   14
#
# FOOLING RATE:  0.0011
# Iteration   15
#
# FOOLING RATE:  0.0015
# Iteration   16
#
# FOOLING RATE:  0.0013
# Iteration   17
#
# FOOLING RATE:  0.001
# Iteration   18
#
# FOOLING RATE:  0.0013
# Iteration   19
#
# FOOLING RATE:  0.0016
# Iteration   20
#
# FOOLING RATE:  0.0011
# Iteration   21
#
# FOOLING RATE:  0.0014
# Iteration   22
#
# FOOLING RATE:  0.001
# Iteration   23
#
# FOOLING RATE:  0.0015
# Iteration   24
#
# FOOLING RATE:  0.0011
# Iteration   25
#
# FOOLING RATE:  0.0012
# Iteration   26
#
# FOOLING RATE:  0.0012
# Iteration   27
#
# FOOLING RATE:  0.0015
# Iteration   28
#
# FOOLING RATE:  0.0012
# Iteration   29
#
# FOOLING RATE:  0.0014
# Iteration   30
#
# FOOLING RATE:  0.0011
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.0032
# Iteration   2
#
# FOOLING RATE:  0.0029
# Iteration   3
#
# FOOLING RATE:  0.0033
# Iteration   4
#
# FOOLING RATE:  0.0032
# Iteration   5
#
# FOOLING RATE:  0.0034
# Iteration   6
#
# FOOLING RATE:  0.0032
# Iteration   7
#
# FOOLING RATE:  0.0031
# Iteration   8
#
# FOOLING RATE:  0.0033
# Iteration   9
#
# FOOLING RATE:  0.0035
# Iteration   10
#
# FOOLING RATE:  0.003
# Iteration   11
#
# FOOLING RATE:  0.0032
# Iteration   12
#
# FOOLING RATE:  0.0032
# Iteration   13
#
# FOOLING RATE:  0.0032
# Iteration   14
#
# FOOLING RATE:  0.0036
# Iteration   15
#
# FOOLING RATE:  0.0032
# Iteration   16
#
# FOOLING RATE:  0.0033
# Iteration   17
#
# FOOLING RATE:  0.0035
# Iteration   18
#
# FOOLING RATE:  0.0034
# Iteration   19
#
# FOOLING RATE:  0.003
# Iteration   20
#
# FOOLING RATE:  0.0032
# Iteration   21
#
# FOOLING RATE:  0.003
# Iteration   22
#
# FOOLING RATE:  0.0032
# Iteration   23
#
# FOOLING RATE:  0.0034
# Iteration   24
#
# FOOLING RATE:  0.0034
# Iteration   25
#
# FOOLING RATE:  0.0034
# Iteration   26
#
# FOOLING RATE:  0.0033
# Iteration   27
#
# FOOLING RATE:  0.0032
# Iteration   28
#
# FOOLING RATE:  0.0034
# Iteration   29
#
# FOOLING RATE:  0.0031
# Iteration   30
#
# FOOLING RATE:  0.003
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.0036
# Iteration   2
#
# FOOLING RATE:  0.0036
# Iteration   3
#
# FOOLING RATE:  0.004
# Iteration   4
#
# FOOLING RATE:  0.0038
# Iteration   5
#
# FOOLING RATE:  0.0042
# Iteration   6
#
# FOOLING RATE:  0.0038
# Iteration   7
#
# FOOLING RATE:  0.004
# Iteration   8
#
# Iteration   17
#
# FOOLING RATE:  0.1221
# Iteration   18
#
# FOOLING RATE:  0.1179
# Iteration   19
#
# FOOLING RATE:  0.1163
# Iteration   20
#
# FOOLING RATE:  0.1154
# Iteration   21
#
# FOOLING RATE:  0.1161
# Iteration   22
#
# FOOLING RATE:  0.1157
# Iteration   23
#
# FOOLING RATE:  0.1117
# Iteration   24
#
# FOOLING RATE:  0.1142
# Iteration   25
#
# FOOLING RATE:  0.1117
# Iteration   26
#
# FOOLING RATE:  0.1178
# Iteration   27
#
# FOOLING RATE:  0.1228
# Iteration   28
#
# FOOLING RATE:  0.1236
# Iteration   29
#
# FOOLING RATE:  0.1266
# Iteration   30
#
# FOOLING RATE:  0.1244
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.0464
# Iteration   2
#
# FOOLING RATE:  0.0631
# Iteration   3
#
# FOOLING RATE:  0.0725
# Iteration   4
#
# FOOLING RATE:  0.0858
# Iteration   5
#
# FOOLING RATE:  0.1007
# Iteration   6
#
# FOOLING RATE:  0.1186
# Iteration   7
#
# FOOLING RATE:  0.159
# Iteration   8
#
# FOOLING RATE:  0.1376
# Iteration   9
#
# FOOLING RATE:  0.1375
# Iteration   10
#
# FOOLING RATE:  0.1323
# Iteration   11
#
# FOOLING RATE:  0.1386
# Iteration   12
#
# FOOLING RATE:  0.136
# Iteration   13
#
# FOOLING RATE:  0.1363
# Iteration   14
#
# FOOLING RATE:  0.1391
# Iteration   15
#
# FOOLING RATE:  0.1376
# Iteration   16
#
# FOOLING RATE:  0.1377
# Iteration   17
#
# FOOLING RATE:  0.144
# Iteration   18
#
# FOOLING RATE:  0.1428
# Iteration   19
#
# FOOLING RATE:  0.1421
# Iteration   20
#
# FOOLING RATE:  0.1429
# Iteration   21
#
# FOOLING RATE:  0.1393
# Iteration   22
#
# FOOLING RATE:  0.1287
# Iteration   23
#
# FOOLING RATE:  0.1377
# Iteration   24
#
# FOOLING RATE:  0.142
# Iteration   25
#
# FOOLING RATE:  0.141
# Iteration   26
#
# FOOLING RATE:  0.1412
# Iteration   27
#
# FOOLING RATE:  0.1505
# Iteration   28
#
# FOOLING RATE:  0.1447
# Iteration   29
#
# FOOLING RATE:  0.14
# Iteration   30
#
# FOOLING RATE:  0.142
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.0427
# Iteration   2
#
# FOOLING RATE:  0.0471
# Iteration   3
#
# FOOLING RATE:  0.0864
# Iteration   4
#
# FOOLING RATE:  0.1383
# Iteration   5
#
# FOOLING RATE:  0.1452
# Iteration   6
#
# FOOLING RATE:  0.1384
# Iteration   7
#
# FOOLING RATE:  0.1399
# Iteration   8
#
# FOOLING RATE:  0.1463
# Iteration   9
#
# FOOLING RATE:  0.1494
# Iteration   10
#
# FOOLING RATE:  0.135
# Iteration   11
#
# FOOLING RATE:  0.1355
# Iteration   12
#
# FOOLING RATE:  0.1359
# Iteration   13
#
# FOOLING RATE:  0.1405
# FOOLING RATE:  0.3475
# Iteration   6
#
# FOOLING RATE:  0.3664
# Iteration   7
#
# FOOLING RATE:  0.3577
# Iteration   8
#
# FOOLING RATE:  0.3782
# Iteration   9
#
# FOOLING RATE:  0.3894
# Iteration   10
#
# FOOLING RATE:  0.4094
# Iteration   11
#
# FOOLING RATE:  0.4119
# Iteration   12
#
# FOOLING RATE:  0.4168
# Iteration   13
#
# FOOLING RATE:  0.4158
# Iteration   14
#
# FOOLING RATE:  0.4252
# Iteration   15
#
# FOOLING RATE:  0.4211
# Iteration   16
#
# FOOLING RATE:  0.4147
# Iteration   17
#
# FOOLING RATE:  0.4084
# Iteration   18
#
# FOOLING RATE:  0.4119
# Iteration   19
#
# FOOLING RATE:  0.4135
# Iteration   20
#
# FOOLING RATE:  0.4107
# Iteration   21
#
# FOOLING RATE:  0.4126
# Iteration   22
#
# FOOLING RATE:  0.4134
# Iteration   23
#
# FOOLING RATE:  0.4229
# Iteration   24
#
# FOOLING RATE:  0.4121
# Iteration   25
#
# FOOLING RATE:  0.4173
# Iteration   26
#
# FOOLING RATE:  0.4147
# Iteration   27
#
# FOOLING RATE:  0.4213
# Iteration   28
#
# FOOLING RATE:  0.4242
# Iteration   29
#
# FOOLING RATE:  0.4228
# Iteration   30
#
# FOOLING RATE:  0.4216
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.2769
# Iteration   2
#
# FOOLING RATE:  0.3182
# Iteration   3
#
# FOOLING RATE:  0.3202
# Iteration   4
#
# FOOLING RATE:  0.3122
# Iteration   5
#
# FOOLING RATE:  0.3218
# Iteration   6
#
# FOOLING RATE:  0.3285
# Iteration   7
#
# FOOLING RATE:  0.3339
# Iteration   8
#
# FOOLING RATE:  0.3428
# Iteration   9
#
# FOOLING RATE:  0.3544
# Iteration   10
#
# FOOLING RATE:  0.3449
# Iteration   11
#
# FOOLING RATE:  0.3452
# Iteration   12
#
# FOOLING RATE:  0.3449
# Iteration   13
#
# FOOLING RATE:  0.3369
# Iteration   14
#
# FOOLING RATE:  0.3379
# Iteration   15
#
# FOOLING RATE:  0.3435
# Iteration   16
#
# FOOLING RATE:  0.3467
# Iteration   17
#
# FOOLING RATE:  0.3514
# Iteration   18
#
# FOOLING RATE:  0.3524
# Iteration   19
#
# FOOLING RATE:  0.348
# Iteration   20
#
# FOOLING RATE:  0.3547
# Iteration   21
#
# FOOLING RATE:  0.351
# Iteration   22
#
# FOOLING RATE:  0.3488
# Iteration   23
#
# FOOLING RATE:  0.3498
# Iteration   24
#
# FOOLING RATE:  0.3539
# Iteration   25
#
# FOOLING RATE:  0.3527
# Iteration   26
#
# FOOLING RATE:  0.3583
# Iteration   27
#
# FOOLING RATE:  0.354
# Iteration   28
#
# FOOLING RATE:  0.3481
# Iteration   29
#
# FOOLING RATE:  0.3555
# Iteration   30
#
# FOOLING RATE:  0.3548
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.2597
# Iteration   2
#
# FOOLING RATE:  0.3448
# Iteration   3
#
# FOOLING RATE:  0.3342
# Iteration   4
#
# FOOLING RATE:  0.3279
# Iteration   5
#
# FOOLING RATE:  0.3166
# Iteration   6
#
# FOOLING RATE:  0.3177
# Iteration   7
#
# FOOLING RATE:  0.3155
# Iteration   8
#
# FOOLING RATE:  0.3205
# Iteration   9
#
# FOOLING RATE:  0.3245
# Iteration   10
#
# FOOLING RATE:  0.3235
# Iteration   11
#
# FOOLING RATE:  0.3285
# Iteration   12
#
# FOOLING RATE:  0.3313
# Iteration   13
#
# FOOLING RATE:  0.3277
# Iteration   14
#
# FOOLING RATE:  0.3299
# Iteration   15
#
# FOOLING RATE:  0.3336
# Iteration   16
#
# FOOLING RATE:  0.3466
# Iteration   17
#
# FOOLING RATE:  0.3381
# Iteration   18
#
# FOOLING RATE:  0.3395
# Iteration   19
#
# FOOLING RATE:  0.339
# Iteration   20
#
# FOOLING RATE:  0.3432
# Iteration   21
#
# FOOLING RATE:  0.3427
# Iteration   22
#
# FOOLING RATE:  0.34
# Iteration   23
#
# FOOLING RATE:  0.3378
# Iteration   24
#
# FOOLING RATE:  0.3364
# Iteration   25
#
# FOOLING RATE:  0.347
# Iteration   26
#
# FOOLING RATE:  0.3403
# Iteration   27
#
# FOOLING RATE:  0.3418
# Iteration   28
#
# FOOLING RATE:  0.3374
# Iteration   29
#
# FOOLING RATE:  0.3384
# Iteration   30
#
# FOOLING RATE:  0.3366
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.2026
# Iteration   2
#
# FOOLING RATE:  0.2331
# Iteration   3
#
# FOOLING RATE:  0.2497
# Iteration   4
#
# FOOLING RATE:  0.2632
# Iteration   5
#
# FOOLING RATE:  0.2929
# Iteration   6
#
# FOOLING RATE:  0.3019
# Iteration   7
#
# FOOLING RATE:  0.308
# Iteration   8
#
# FOOLING RATE:  0.3134
# Iteration   9
#
# FOOLING RATE:  0.3182
# Iteration   10
#
# FOOLING RATE:  0.3215
# Iteration   11
#
# FOOLING RATE:  0.3305
# Iteration   12
#
# FOOLING RATE:  0.3338
# Iteration   13
#
# FOOLING RATE:  0.3443
# Iteration   14
#
# FOOLING RATE:  0.3427
# Iteration   15
#
# FOOLING RATE:  0.3469
# Iteration   16
#
# FOOLING RATE:  0.3468
# Iteration   17
#
# FOOLING RATE:  0.3536
# Iteration   18
#
# FOOLING RATE:  0.3527
# Iteration   19
#
# FOOLING RATE:  0.3584
# Iteration   20
#
# FOOLING RATE:  0.3596
# Iteration   21
#
# FOOLING RATE:  0.3613
# Iteration   22
#
# FOOLING RATE:  0.3643
# Iteration   23
#
# FOOLING RATE:  0.3662
# Iteration   24
#
# FOOLING RATE:  0.3681
# Iteration   25
#
# FOOLING RATE:  0.3626
# Iteration   26
#
# FOOLING RATE:  0.3653
# Iteration   27
#
# FOOLING RATE:  0.3649
# Iteration   28
#
# FOOLING RATE:  0.3655
# Iteration   29
#
# FOOLING RATE:  0.3662
# Iteration   30
#
# FOOLING RATE:  0.3689
# Iteration   28
#
# FOOLING RATE:  0.5321
# Iteration   29
#
# FOOLING RATE:  0.5276
# Iteration   30
#
# FOOLING RATE:  0.5331
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.2842
# Iteration   2
#
# FOOLING RATE:  0.2686
# Iteration   3
#
# FOOLING RATE:  0.2564
# Iteration   4
#
# FOOLING RATE:  0.2726
# Iteration   5
#
# FOOLING RATE:  0.3436
# Iteration   6
#
# FOOLING RATE:  0.401
# Iteration   7
#
# FOOLING RATE:  0.4336
# Iteration   8
#
# FOOLING RATE:  0.4945
# Iteration   9
#
# FOOLING RATE:  0.5121
# Iteration   10
#
# FOOLING RATE:  0.5175
# Iteration   11
#
# FOOLING RATE:  0.513
# Iteration   12
#
# FOOLING RATE:  0.5086
# Iteration   13
#
# FOOLING RATE:  0.5021
# Iteration   14
#
# FOOLING RATE:  0.5044
# Iteration   15
#
# FOOLING RATE:  0.5028
# Iteration   16
#
# FOOLING RATE:  0.5042
# Iteration   17
#
# FOOLING RATE:  0.505
# Iteration   18
#
# FOOLING RATE:  0.5103
# Iteration   19
#
# FOOLING RATE:  0.5049
# Iteration   20
#
# FOOLING RATE:  0.5015
# Iteration   21
#
# FOOLING RATE:  0.5005
# Iteration   22
#
# FOOLING RATE:  0.5031
# Iteration   23
#
# FOOLING RATE:  0.5038
# Iteration   24
#
# FOOLING RATE:  0.5043
# Iteration   25
#
# FOOLING RATE:  0.5088
# Iteration   26
#
# FOOLING RATE:  0.5083
# Iteration   27
#
# FOOLING RATE:  0.511
# Iteration   28
#
# FOOLING RATE:  0.5121
# Iteration   29
#
# FOOLING RATE:  0.5077
# Iteration   30
#
# FOOLING RATE:  0.5113
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.4471
# Iteration   2
#
# FOOLING RATE:  0.5015
# Iteration   3
#
# FOOLING RATE:  0.5106
# Iteration   4
#
# FOOLING RATE:  0.5225
# Iteration   5
#
# FOOLING RATE:  0.5186
# Iteration   6
#
# FOOLING RATE:  0.5155
# Iteration   7
#
# FOOLING RATE:  0.5177
# Iteration   8
#
# FOOLING RATE:  0.5163
# Iteration   9
#
# FOOLING RATE:  0.5197
# Iteration   10
#
# FOOLING RATE:  0.5213
# Iteration   11
#
# FOOLING RATE:  0.5189
# Iteration   12
#
# FOOLING RATE:  0.5215
# Iteration   13
#
# FOOLING RATE:  0.5236
# Iteration   14
#
# FOOLING RATE:  0.5268
# Iteration   15
#
# FOOLING RATE:  0.5269
# Iteration   16
#
# FOOLING RATE:  0.5277
# Iteration   17
#
# FOOLING RATE:  0.5298
# Iteration   18
#
# FOOLING RATE:  0.531
# Iteration   19
#
# FOOLING RATE:  0.5356
# Iteration   20
#
# FOOLING RATE:  0.5366
# Iteration   21
#
# FOOLING RATE:  0.5401
# Iteration   22
#
# FOOLING RATE:  0.5427
# Iteration   23
#
# FOOLING RATE:  0.5424
# Iteration   24
#
# FOOLING RATE:  0.5417
# Iteration   25
#
# FOOLING RATE:  0.5408
# Iteration   26
#
# FOOLING RATE:  0.5395
# Iteration   27
#
# FOOLING RATE:  0.5382
# Iteration   28
#
# FOOLING RATE:  0.5381
# Iteration   29
#
# FOOLING RATE:  0.5376
# Iteration   30
#
# FOOLING RATE:  0.5385
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.345
# Iteration   2
#
# FOOLING RATE:  0.4403
# Iteration   3
#
# FOOLING RATE:  0.4772
# Iteration   4
#
# FOOLING RATE:  0.4868
# Iteration   5
#
# FOOLING RATE:  0.4941
# Iteration   6
#
# FOOLING RATE:  0.4849
# Iteration   7
#
# FOOLING RATE:  0.4771
# Iteration   8
#
# FOOLING RATE:  0.48
# Iteration   9
#
# FOOLING RATE:  0.4803
# Iteration   10
#
# FOOLING RATE:  0.4812
# Iteration   11
#
# FOOLING RATE:  0.4816
# Iteration   12
#
# FOOLING RATE:  0.4837
# Iteration   13
#
# FOOLING RATE:  0.4855
# Iteration   14
#
# FOOLING RATE:  0.4856
# Iteration   15
#
# FOOLING RATE:  0.4906
# Iteration   16
#
# FOOLING RATE:  0.4927
# Iteration   17
#
# FOOLING RATE:  0.4907
# Iteration   18
#
# FOOLING RATE:  0.4893
# Iteration   19
#
# FOOLING RATE:  0.4915
# Iteration   20
#
# FOOLING RATE:  0.4936
# Iteration   21
#
# FOOLING RATE:  0.4947
# Iteration   22
#
# FOOLING RATE:  0.4968
# Iteration   23
#
# FOOLING RATE:  0.4995
# Iteration   24
#
# FOOLING RATE:  0.4999
# Iteration   25
#
# FOOLING RATE:  0.5021
# Iteration   26
#
# FOOLING RATE:  0.5028
# Iteration   27
#
# FOOLING RATE:  0.5021
# Iteration   28
#
# FOOLING RATE:  0.5019
# Iteration   29
#
# FOOLING RATE:  0.5016
# Iteration   30
#
# FOOLING RATE:  0.5028
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.4223
# Iteration   2
#
# FOOLING RATE:  0.4838
# Iteration   3
#
# FOOLING RATE:  0.487
# Iteration   4
#
# FOOLING RATE:  0.5045
# Iteration   5
#
# FOOLING RATE:  0.5167
# Iteration   6
#
# FOOLING RATE:  0.5233
# Iteration   7
#
# FOOLING RATE:  0.5267
# Iteration   8
#
# FOOLING RATE:  0.5281
# Iteration   9
#
# FOOLING RATE:  0.5349
# Iteration   10
#
# FOOLING RATE:  0.5467
# Iteration   11
#
# FOOLING RATE:  0.5513
# Iteration   12
#
# FOOLING RATE:  0.5543
# Iteration   13
#
# FOOLING RATE:  0.5626
# Iteration   14
#
# FOOLING RATE:  0.5644
# Iteration   15
#
# FOOLING RATE:  0.5673
# Iteration   16
#
# FOOLING RATE:  0.5724
# Iteration   17
#
# FOOLING RATE:  0.5729
# Iteration   18
#
# FOOLING RATE:  0.5752
# Iteration   19
#
# FOOLING RATE:  0.5741
# Iteration   20
#
# FOOLING RATE:  0.5748
# Iteration   21
#
# FOOLING RATE:  0.5754
# Iteration   22
#
# FOOLING RATE:  0.5757
# Iteration   23
#
# FOOLING RATE:  0.5789
# Iteration   24
#
# FOOLING RATE:  0.577
# Iteration   25
#
# FOOLING RATE:  0.5761
# Iteration   26
#
# FOOLING RATE:  0.5751
# Iteration   27
#
# FOOLING RATE:  0.5763
# Iteration   28
#
# FOOLING RATE:  0.5748
# Iteration   29
#
# FOOLING RATE:  0.5743
# Iteration   30
#
# FOOLING RATE:  0.577
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.4609
# Iteration   2
#
# FOOLING RATE:  0.4943
# Iteration   3
#
# FOOLING RATE:  0.5089
# Iteration   4
#
# FOOLING RATE:  0.5061
# Iteration   5
#
# FOOLING RATE:  0.5222
# Iteration   6
#
# FOOLING RATE:  0.5165
# Iteration   7
#
# FOOLING RATE:  0.5145
# Iteration   8
#
# FOOLING RATE:  0.5134
# Iteration   9
#
# FOOLING RATE:  0.5208
# Iteration   10
#
# FOOLING RATE:  0.5338
# Iteration   11
#
# FOOLING RATE:  0.546
# Iteration   12
#
# FOOLING RATE:  0.5583
# Iteration   13
#
# FOOLING RATE:  0.5677
# Iteration   14
#
# FOOLING RATE:  0.5748
# Iteration   15
#
# FOOLING RATE:  0.5809
# Iteration   16
#
# FOOLING RATE:  0.585
# Iteration   17
#
# FOOLING RATE:  0.588
# Iteration   18
#
# FOOLING RATE:  0.5907
# Iteration   19
#
# FOOLING RATE:  0.5952
# Iteration   20
#
# FOOLING RATE:  0.5959
# Iteration   21
#
# FOOLING RATE:  0.5975
# Iteration   22
#
# FOOLING RATE:  0.5998
# Iteration   23
#
# FOOLING RATE:  0.6007
# Iteration   24
#
# FOOLING RATE:  0.6022
# Iteration   25
#
# FOOLING RATE:  0.604
# Iteration   26
#
# FOOLING RATE:  0.6061
# Iteration   27
#
# FOOLING RATE:  0.6071
# Iteration   28
#
# FOOLING RATE:  0.6098
# Iteration   29
#
# FOOLING RATE:  0.6109
# Iteration   30
#
# FOOLING RATE:  0.612
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.5129
# Iteration   2
#
# FOOLING RATE:  0.5337
# Iteration   3
#
# FOOLING RATE:  0.5347
# Iteration   4
#
# FOOLING RATE:  0.542
# Iteration   5
#
# FOOLING RATE:  0.5488
# Iteration   6
#
# FOOLING RATE:  0.5498
# Iteration   7
#
# FOOLING RATE:  0.5526
# Iteration   8
#
# FOOLING RATE:  0.5567
# Iteration   9
#
# FOOLING RATE:  0.5607
# Iteration   10
#
# FOOLING RATE:  0.5632
# Iteration   11
#
# FOOLING RATE:  0.5685
# Iteration   12
#
# FOOLING RATE:  0.5724
# Iteration   13
#
# FOOLING RATE:  0.5713
# Iteration   14
#
# FOOLING RATE:  0.5719
# Iteration   15
#
# FOOLING RATE:  0.5722
# Iteration   16
#
# FOOLING RATE:  0.5739
# Iteration   17
#
# FOOLING RATE:  0.5764
# Iteration   18
#
# FOOLING RATE:  0.5755
# Iteration   19
#
# FOOLING RATE:  0.5758
# Iteration   20
#
# FOOLING RATE:  0.5747
# Iteration   21
#
# FOOLING RATE:  0.5747
# Iteration   22
#
# FOOLING RATE:  0.5757
# Iteration   23
#
# FOOLING RATE:  0.5772
# Iteration   24
#
# FOOLING RATE:  0.5765
# Iteration   25
#
# FOOLING RATE:  0.5773
# Iteration   26
#
# FOOLING RATE:  0.5775
# Iteration   27
#
# FOOLING RATE:  0.5786
# Iteration   28
#
# FOOLING RATE:  0.5778
# Iteration   29
#
# FOOLING RATE:  0.5771
# Iteration   30
#
# FOOLING RATE:  0.5776
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.4599
# Iteration   2
#
# FOOLING RATE:  0.4885
# Iteration   3
#
# FOOLING RATE:  0.5174
# Iteration   4
#
# FOOLING RATE:  0.5366
# Iteration   5
#
# FOOLING RATE:  0.5492
# Iteration   6
#
# FOOLING RATE:  0.5535
# Iteration   7
#
# FOOLING RATE:  0.5562
# Iteration   8
#
# FOOLING RATE:  0.5573
# Iteration   9
#
# FOOLING RATE:  0.5591
# Iteration   10
#
# FOOLING RATE:  0.5636
# Iteration   11
#
# FOOLING RATE:  0.5661
# Iteration   12
#
# FOOLING RATE:  0.5684
# Iteration   13
#
# FOOLING RATE:  0.5701
# Iteration   14
#
# FOOLING RATE:  0.5715
# Iteration   15
#
# FOOLING RATE:  0.5733
# Iteration   16
#
# FOOLING RATE:  0.5743
# Iteration   17
#
# FOOLING RATE:  0.5763
# Iteration   18
#
# FOOLING RATE:  0.5769
# Iteration   19
#
# FOOLING RATE:  0.5773
# Iteration   20
#
# FOOLING RATE:  0.5773
# Iteration   21
#
# FOOLING RATE:  0.5781
# Iteration   22
#
# FOOLING RATE:  0.5793
# Iteration   23
#
# FOOLING RATE:  0.5795
# Iteration   24
#
# FOOLING RATE:  0.5798
# Iteration   25
#
# FOOLING RATE:  0.58
# Iteration   26
#
# FOOLING RATE:  0.5804
# Iteration   27
#
# FOOLING RATE:  0.5804
# Iteration   28
#
# FOOLING RATE:  0.5806
# Iteration   29
#
# FOOLING RATE:  0.5805
# Iteration   30
#
# FOOLING RATE:  0.5805
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.5149
# Iteration   2
#
# FOOLING RATE:  0.5866
# Iteration   3
#
# FOOLING RATE:  0.59
# Iteration   4
#
# FOOLING RATE:  0.5871
# Iteration   5
#
# FOOLING RATE:  0.5828
# Iteration   6
#
# FOOLING RATE:  0.5808
# Iteration   7
#
# FOOLING RATE:  0.5805
# Iteration   8
#
# FOOLING RATE:  0.5782
# Iteration   9
#
# FOOLING RATE:  0.5777
# Iteration   10
#
# FOOLING RATE:  0.5774
# Iteration   11
#
# FOOLING RATE:  0.5778
# Iteration   12
#
# FOOLING RATE:  0.5772
# Iteration   13
#
# FOOLING RATE:  0.5775
# Iteration   14
#
# FOOLING RATE:  0.5745
# Iteration   15
#
# FOOLING RATE:  0.5746
# Iteration   16
#
# FOOLING RATE:  0.5742
# Iteration   17
#
# FOOLING RATE:  0.5758
# Iteration   18
#
# FOOLING RATE:  0.5754
# Iteration   19
#
# FOOLING RATE:  0.5754
# Iteration   20
#
# FOOLING RATE:  0.5758
# Iteration   21
#
# FOOLING RATE:  0.5766
# Iteration   22
#
# FOOLING RATE:  0.5767
# Iteration   23
#
# FOOLING RATE:  0.5771
# Iteration   24
#
# FOOLING RATE:  0.5768
# Iteration   25
#
# FOOLING RATE:  0.577
# Iteration   26
#
# FOOLING RATE:  0.5763
# Iteration   27
#
# FOOLING RATE:  0.5767
# Iteration   28
#
# FOOLING RATE:  0.5776
# Iteration   29
#
# FOOLING RATE:  0.5775
# Iteration   30
#
# FOOLING RATE:  0.5763
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.4906
# Iteration   2
#
# FOOLING RATE:  0.4071
# Iteration   3
#
# FOOLING RATE:  0.3906
# Iteration   4
#
# FOOLING RATE:  0.3695
# Iteration   5
#
# FOOLING RATE:  0.3624
# Iteration   6
#
# FOOLING RATE:  0.3631
# Iteration   7
#
# FOOLING RATE:  0.3693
# Iteration   8
#
# FOOLING RATE:  0.3777
# Iteration   9
#
# FOOLING RATE:  0.3852
# Iteration   10
#
# FOOLING RATE:  0.3896
# Iteration   11
#
# FOOLING RATE:  0.3926
# Iteration   12
#
# FOOLING RATE:  0.3954
# Iteration   13
#
# FOOLING RATE:  0.4011
# Iteration   14
#
# FOOLING RATE:  0.4085
# Iteration   15
#
# FOOLING RATE:  0.4119
# Iteration   16
#
# FOOLING RATE:  0.418
# Iteration   17
#
# FOOLING RATE:  0.4179
# Iteration   18
#
# FOOLING RATE:  0.4215
# Iteration   19
#
# FOOLING RATE:  0.4229
# Iteration   20
#
# FOOLING RATE:  0.4252
# Iteration   21
#
# FOOLING RATE:  0.4309
# Iteration   22
#
# FOOLING RATE:  0.4357
# Iteration   23
#
# FOOLING RATE:  0.4402
# Iteration   24
#
# FOOLING RATE:  0.4432
# Iteration   25
#
# FOOLING RATE:  0.4525
# Iteration   26
#
# FOOLING RATE:  0.4622
# Iteration   27
#
# FOOLING RATE:  0.467
# Iteration   28
#
# FOOLING RATE:  0.4713
# Iteration   29
#
# ...
# Iteration   11
#
# FOOLING RATE:  0.7091
# Iteration   12
#
# FOOLING RATE:  0.7097
# Iteration   13
#
# FOOLING RATE:  0.7099
# Iteration   14
#
# FOOLING RATE:  0.7094
# Iteration   15
#
# FOOLING RATE:  0.7092
# Iteration   16
#
# FOOLING RATE:  0.7095
# Iteration   17
#
# FOOLING RATE:  0.7096
# Iteration   18
#
# FOOLING RATE:  0.7102
# Iteration   19
#
# FOOLING RATE:  0.7102
# Iteration   20
#
# FOOLING RATE:  0.7109
# Iteration   21
#
# FOOLING RATE:  0.7111
# Iteration   22
#
# FOOLING RATE:  0.7116
# Iteration   23
#
# FOOLING RATE:  0.7116
# Iteration   24
#
# FOOLING RATE:  0.7117
# Iteration   25
#
# FOOLING RATE:  0.7118
# Iteration   26
#
# FOOLING RATE:  0.7118
# Iteration   27
#
# FOOLING RATE:  0.7118
# Iteration   28
#
# FOOLING RATE:  0.7119
# Iteration   29
#
# FOOLING RATE:  0.7121
# Iteration   30
#
# FOOLING RATE:  0.7122
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.6498
# Iteration   2
#
# FOOLING RATE:  0.6874
# Iteration   3
#
# FOOLING RATE:  0.7172
# Iteration   4
#
# FOOLING RATE:  0.7393
# Iteration   5
#
# FOOLING RATE:  0.7583
# Iteration   6
#
# FOOLING RATE:  0.7689
# Iteration   7
#
# FOOLING RATE:  0.775
# Iteration   8
#
# FOOLING RATE:  0.7793
# Iteration   9
#
# FOOLING RATE:  0.7824
# Iteration   10
#
# FOOLING RATE:  0.7841
# Iteration   11
#
# FOOLING RATE:  0.7859
# Iteration   12
#
# FOOLING RATE:  0.7877
# Iteration   13
#
# FOOLING RATE:  0.7886
# Iteration   14
#
# FOOLING RATE:  0.7902
# Iteration   15
#
# FOOLING RATE:  0.7908
# Iteration   16
#
# FOOLING RATE:  0.791
# Iteration   17
#
# FOOLING RATE:  0.7918
# Iteration   18
#
# FOOLING RATE:  0.7926
# Iteration   19
#
# FOOLING RATE:  0.7926
# Iteration   20
#
# FOOLING RATE:  0.7927
# Iteration   21
#
# FOOLING RATE:  0.7927
# Iteration   22
#
# FOOLING RATE:  0.7929
# Iteration   23
#
# FOOLING RATE:  0.7932
# Iteration   24
#
# FOOLING RATE:  0.7932
# Iteration   25
#
# FOOLING RATE:  0.7934
# Iteration   26
#
# FOOLING RATE:  0.7934
# Iteration   27
#
# FOOLING RATE:  0.7933
# Iteration   28
#
# FOOLING RATE:  0.7932
# Iteration   29
#
# FOOLING RATE:  0.7934
# Iteration   30
#
# FOOLING RATE:  0.7933
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.6309
# Iteration   2
#
# FOOLING RATE:  0.661
# Iteration   3
#
# FOOLING RATE:  0.6713
# Iteration   4
#
# FOOLING RATE:  0.6803
# Iteration   5
#
# FOOLING RATE:  0.6848
# Iteration   6
#
# FOOLING RATE:  0.6882
# Iteration   7
#
# FOOLING RATE:  0.6918
# Iteration   8
#
# FOOLING RATE:  0.6952
# Iteration   9
#
# FOOLING RATE:  0.697
# Iteration   10
#
# FOOLING RATE:  0.6985
# Iteration   11
#
# FOOLING RATE:  0.6998
# Iteration   12
#
# FOOLING RATE:  0.7014
# Iteration   13
#
# FOOLING RATE:  0.7029
# Iteration   14
#
# FOOLING RATE:  0.7047
# Iteration   15
#
# FOOLING RATE:  0.7054
# Iteration   16
#
# FOOLING RATE:  0.7062
# Iteration   17
#
# FOOLING RATE:  0.707
# Iteration   18
#
# FOOLING RATE:  0.7079
# Iteration   19
#
# FOOLING RATE:  0.7085
# Iteration   20
#
# FOOLING RATE:  0.7089
# Iteration   21
#
# FOOLING RATE:  0.7099
# Iteration   22
#
# FOOLING RATE:  0.7101
# Iteration   23
#
# FOOLING RATE:  0.7104
# Iteration   24
#
# FOOLING RATE:  0.7104
# Iteration   25
#
# FOOLING RATE:  0.7113
# Iteration   26
#
# FOOLING RATE:  0.7116
# Iteration   27
#
# FOOLING RATE:  0.7119
# Iteration   28
#
# FOOLING RATE:  0.7121
# Iteration   29
#
# FOOLING RATE:  0.7122
# Iteration   30
#
# FOOLING RATE:  0.7127
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.5392
# Iteration   2
#
# FOOLING RATE:  0.5836
# Iteration   3
#
# FOOLING RATE:  0.6006
# Iteration   4
#
# FOOLING RATE:  0.6072
# Iteration   5
#
# FOOLING RATE:  0.6147
# Iteration   6
#
# FOOLING RATE:  0.6198
# Iteration   7
#
# FOOLING RATE:  0.6238
# Iteration   8
#
# FOOLING RATE:  0.6265
# Iteration   9
#
# FOOLING RATE:  0.6292
# Iteration   10
#
# FOOLING RATE:  0.6317
# Iteration   11
#
# FOOLING RATE:  0.6337
# Iteration   12
#
# FOOLING RATE:  0.6359
# Iteration   13
#
# FOOLING RATE:  0.6358
# Iteration   14
#
# FOOLING RATE:  0.6377
# Iteration   15
#
# FOOLING RATE:  0.6387
# Iteration   16
#
# FOOLING RATE:  0.6396
# Iteration   17
#
# FOOLING RATE:  0.6405
# Iteration   18
#
# FOOLING RATE:  0.6412
# Iteration   19
#
# FOOLING RATE:  0.6419
# Iteration   20
#
# FOOLING RATE:  0.642
# Iteration   21
#
# FOOLING RATE:  0.6423
# Iteration   22
#
# FOOLING RATE:  0.6428
# Iteration   23
#
# FOOLING RATE:  0.643
# Iteration   24
#
# FOOLING RATE:  0.6432
# Iteration   25
#
# FOOLING RATE:  0.6431
# Iteration   26
#
# FOOLING RATE:  0.6436
# Iteration   27
#
# FOOLING RATE:  0.6441
# Iteration   28
#
# FOOLING RATE:  0.6441
# Iteration   29
#
# FOOLING RATE:  0.6445
# Iteration   30
#
# FOOLING RATE:  0.6447
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.5946
# Iteration   2
#
# FOOLING RATE:  0.6226
# Iteration   3
#
# FOOLING RATE:  0.6353
# Iteration   4
#
# FOOLING RATE:  0.6417
# Iteration   5
#
# FOOLING RATE:  0.6494
# Iteration   6
#
# FOOLING RATE:  0.6546
# Iteration   7
#
# FOOLING RATE:  0.6583
# Iteration   8
#
# FOOLING RATE:  0.6622
# Iteration   9
#
# FOOLING RATE:  0.6656
# Iteration   10
#
# FOOLING RATE:  0.6683
# Iteration   11
#
# FOOLING RATE:  0.6706
# Iteration   12
#
# FOOLING RATE:  0.6726
# Iteration   13
#
# FOOLING RATE:  0.674
# Iteration   14
#
# FOOLING RATE:  0.6752
# Iteration   15
#
# FOOLING RATE:  0.6761
# Iteration   16
#
# FOOLING RATE:  0.6777
# Iteration   17
#
# FOOLING RATE:  0.6802
# Iteration   18
#
# FOOLING RATE:  0.681
# Iteration   19
#
# FOOLING RATE:  0.6813
# Iteration   20
#
# FOOLING RATE:  0.6816
# Iteration   21
#
# FOOLING RATE:  0.6824
# Iteration   22
#
# FOOLING RATE:  0.6834
# Iteration   23
#
# FOOLING RATE:  0.6839
# Iteration   24
#
# FOOLING RATE:  0.6841
# Iteration   25
#
# FOOLING RATE:  0.6848
# Iteration   26
#
# FOOLING RATE:  0.6849
# Iteration   27
#
# FOOLING RATE:  0.6855
# Iteration   28
#
# FOOLING RATE:  0.686
# Iteration   29
#
# FOOLING RATE:  0.686
# Iteration   30
#
# FOOLING RATE:  0.6863
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.6678
# Iteration   2
#
# FOOLING RATE:  0.7147
# Iteration   3
#
# FOOLING RATE:  0.7413
# Iteration   4
#
# FOOLING RATE:  0.7577
# Iteration   5
#
# FOOLING RATE:  0.7687
# Iteration   6
#
# FOOLING RATE:  0.7749
# Iteration   7
#
# FOOLING RATE:  0.7788
# Iteration   8
#
# FOOLING RATE:  0.7826
# Iteration   9
#
# FOOLING RATE:  0.7849
# Iteration   10
#
# FOOLING RATE:  0.7866
# Iteration   11
#
# FOOLING RATE:  0.7882
# Iteration   12
#
# FOOLING RATE:  0.7897
# Iteration   13
#
# FOOLING RATE:  0.791
# Iteration   14
#
# FOOLING RATE:  0.7921
# Iteration   15
#
# FOOLING RATE:  0.7926
# Iteration   16
#
# FOOLING RATE:  0.7931
# Iteration   17
#
# FOOLING RATE:  0.7938
# Iteration   18
#
# FOOLING RATE:  0.794
# Iteration   19
#
# FOOLING RATE:  0.7946
# Iteration   20
#
# FOOLING RATE:  0.795
# Iteration   21
#
# FOOLING RATE:  0.7952
# Iteration   22
#
# FOOLING RATE:  0.7953
# Iteration   23
#
# FOOLING RATE:  0.7953
# Iteration   24
#
# FOOLING RATE:  0.7952
# Iteration   25
#
# FOOLING RATE:  0.7953
# Iteration   26
#
# FOOLING RATE:  0.7953
# Iteration   27
#
# FOOLING RATE:  0.7953
# Iteration   28
#
# FOOLING RATE:  0.7953
# Iteration   29
#
# FOOLING RATE:  0.7954
# Iteration   30
#
# FOOLING RATE:  0.7955
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.6662
# Iteration   2
#
# FOOLING RATE:  0.7118
# Iteration   3
#
# FOOLING RATE:  0.7377
# Iteration   4
#
# FOOLING RATE:  0.751
# Iteration   5
#
# FOOLING RATE:  0.7618
# Iteration   6
#
# FOOLING RATE:  0.7696
# Iteration   7
#
# FOOLING RATE:  0.774
# Iteration   8
#
# FOOLING RATE:  0.7784
# Iteration   9
#
# FOOLING RATE:  0.7811
# Iteration   10
#
# FOOLING RATE:  0.7845
# Iteration   11
#
# FOOLING RATE:  0.7872
# Iteration   12
#
# FOOLING RATE:  0.7887
# Iteration   13
#
# FOOLING RATE:  0.7891
# Iteration   14
#
# FOOLING RATE:  0.7909
# Iteration   15
#
# FOOLING RATE:  0.7915
# Iteration   16
#
# FOOLING RATE:  0.7921
# Iteration   17
#
# FOOLING RATE:  0.7931
# Iteration   18
#
# FOOLING RATE:  0.7932
# Iteration   19
#
# FOOLING RATE:  0.7932
# Iteration   20
#
# FOOLING RATE:  0.7939
# Iteration   21
#
# FOOLING RATE:  0.7943
# Iteration   22
#
# FOOLING RATE:  0.7948
# Iteration   23
#
# FOOLING RATE:  0.7948
# Iteration   24
#
# FOOLING RATE:  0.795
# Iteration   25
#
# FOOLING RATE:  0.7952
# Iteration   26
#
# FOOLING RATE:  0.7952
# Iteration   27
#
# FOOLING RATE:  0.7955
# Iteration   28
#
# FOOLING RATE:  0.7955
# Iteration   29
#
# FOOLING RATE:  0.7957
# Iteration   30
#
# FOOLING RATE:  0.7959
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.6928
# Iteration   2
#
# FOOLING RATE:  0.7366
# Iteration   3
#
# FOOLING RATE:  0.754
# Iteration   4
#
# FOOLING RATE:  0.765
# Iteration   5
#
# FOOLING RATE:  0.7704
# Iteration   6
#
# FOOLING RATE:  0.775
# Iteration   7
#
# FOOLING RATE:  0.7792
# Iteration   8
#
# FOOLING RATE:  0.7825
# Iteration   9
#
# FOOLING RATE:  0.7844
# Iteration   10
#
# FOOLING RATE:  0.7865
# Iteration   11
#
# FOOLING RATE:  0.7874
# Iteration   12
#
# FOOLING RATE:  0.7887
# Iteration   13
#
# FOOLING RATE:  0.7903
# Iteration   14
#
# FOOLING RATE:  0.7914
# Iteration   15
#
# FOOLING RATE:  0.7918
# Iteration   16
#
# FOOLING RATE:  0.792
# Iteration   17
#
# FOOLING RATE:  0.7924
# Iteration   18
#
# FOOLING RATE:  0.7927
# Iteration   19
#
# FOOLING RATE:  0.7935
# Iteration   20
#
# FOOLING RATE:  0.7936
# Iteration   21
#
# FOOLING RATE:  0.7939
# Iteration   22
#
# FOOLING RATE:  0.7943
# Iteration   23
#
# FOOLING RATE:  0.7945
# Iteration   24
#
# FOOLING RATE:  0.7948
# Iteration   25
#
# FOOLING RATE:  0.7951
# Iteration   26
#
# FOOLING RATE:  0.7952
# Iteration   27
#
# FOOLING RATE:  0.7952
# Iteration   28
#
# FOOLING RATE:  0.7952
# Iteration   29
#
# FOOLING RATE:  0.7954
# Iteration   30
#
# FOOLING RATE:  0.7954
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.5278
# Iteration   2
#
# FOOLING RATE:  0.6184
# Iteration   3
#
# FOOLING RATE:  0.6539
# Iteration   4
#
# FOOLING RATE:  0.6746
# Iteration   5
#
# FOOLING RATE:  0.6859
# Iteration   6
#
# FOOLING RATE:  0.6966
# Iteration   7
#
# FOOLING RATE:  0.7021
# Iteration   8
#
# FOOLING RATE:  0.7094
# Iteration   9
#
# FOOLING RATE:  0.7122
# Iteration   10
#
# FOOLING RATE:  0.7129
# Iteration   11
#
# FOOLING RATE:  0.7152
# Iteration   12
#
# FOOLING RATE:  0.7165
# Iteration   13
#
# FOOLING RATE:  0.7169
# Iteration   14
#
# FOOLING RATE:  0.7178
# Iteration   15
#
# FOOLING RATE:  0.7193
# Iteration   16
#
# FOOLING RATE:  0.7214
# Iteration   17
#
# FOOLING RATE:  0.7221
# Iteration   18
#
# FOOLING RATE:  0.7229
# Iteration   19
#
# FOOLING RATE:  0.723
# Iteration   20
#
# FOOLING RATE:  0.7242
# Iteration   21
#
# FOOLING RATE:  0.7252
# Iteration   22
#
# FOOLING RATE:  0.7257
# Iteration   23
#
# FOOLING RATE:  0.7257
# Iteration   24
#
# FOOLING RATE:  0.726
# Iteration   25
#
# FOOLING RATE:  0.7255
# Iteration   26
#
# FOOLING RATE:  0.7253
# Iteration   27
#
# FOOLING RATE:  0.7252
# Iteration   28
#
# FOOLING RATE:  0.7251
# Iteration   29
#
# FOOLING RATE:  0.7248
# Iteration   30
#
# FOOLING RATE:  0.7249
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.6849
# Iteration   2
#
# FOOLING RATE:  0.7248
# Iteration   3
#
# FOOLING RATE:  0.7398
# Iteration   4
#
# FOOLING RATE:  0.7497
# Iteration   5
#
# FOOLING RATE:  0.7563
# Iteration   6
#
# FOOLING RATE:  0.7602
# Iteration   7
#
# FOOLING RATE:  0.7626
# Iteration   8
#
# FOOLING RATE:  0.7642
# Iteration   9
#
# FOOLING RATE:  0.7659
# Iteration   10
#
# FOOLING RATE:  0.767
# Iteration   11
#
# FOOLING RATE:  0.7682
# Iteration   12
#
# FOOLING RATE:  0.7692
# Iteration   13
#
# FOOLING RATE:  0.7707
# Iteration   14
#
# FOOLING RATE:  0.771
# Iteration   15
#
# FOOLING RATE:  0.7715
# Iteration   16
#
# FOOLING RATE:  0.7721
# Iteration   17
#
# FOOLING RATE:  0.7723
# Iteration   18
#
# FOOLING RATE:  0.7726
# Iteration   19
#
# FOOLING RATE:  0.7729
# Iteration   20
#
# FOOLING RATE:  0.7729
# Iteration   21
#
# FOOLING RATE:  0.7732
# Iteration   22
#
# FOOLING RATE:  0.7731
# Iteration   23
#
# FOOLING RATE:  0.7731
# Iteration   24
#
# FOOLING RATE:  0.7732
# Iteration   25
#
# FOOLING RATE:  0.773
# Iteration   26
#
# FOOLING RATE:  0.7731
# Iteration   27
#
# FOOLING RATE:  0.773
# Iteration   28
#
# FOOLING RATE:  0.7731
# Iteration   29
#
# FOOLING RATE:  0.7731
# Iteration   30
#
# FOOLING RATE:  0.7731
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.6963
# Iteration   2
#
# FOOLING RATE:  0.6644
# Iteration   3
#
# FOOLING RATE:  0.6636
# Iteration   4
#
# FOOLING RATE:  0.6652
# Iteration   5
#
# FOOLING RATE:  0.6698
# Iteration   6
#
# FOOLING RATE:  0.6716
# Iteration   7
#
# FOOLING RATE:  0.6777
# Iteration   8
#
# FOOLING RATE:  0.6784
# Iteration   9
#
# FOOLING RATE:  0.6814
# Iteration   10
#
# FOOLING RATE:  0.6846
# Iteration   11
#
# FOOLING RATE:  0.6873
# Iteration   12
#
# FOOLING RATE:  0.6892
# Iteration   13
#
# FOOLING RATE:  0.6905
# Iteration   14
#
# FOOLING RATE:  0.6908
# Iteration   15
#
# FOOLING RATE:  0.6929
# Iteration   16
#
# FOOLING RATE:  0.6941
# Iteration   17
#
# FOOLING RATE:  0.6956
# Iteration   18
#
# FOOLING RATE:  0.6969
# Iteration   19
#
# FOOLING RATE:  0.6978
# Iteration   20
#
# FOOLING RATE:  0.6982
# Iteration   21
#
# FOOLING RATE:  0.6994
# Iteration   22
#
# FOOLING RATE:  0.6996
# Iteration   23
#
# FOOLING RATE:  0.7004
# Iteration   24
#
# FOOLING RATE:  0.7011
# Iteration   25
#
# FOOLING RATE:  0.7014
# Iteration   26
#
# FOOLING RATE:  0.702
# Iteration   27
#
# FOOLING RATE:  0.7022
# Iteration   28
#
# FOOLING RATE:  0.7024
# Iteration   29
#
# FOOLING RATE:  0.7025
# Iteration   30
#
# FOOLING RATE:  0.7027
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.4783
# Iteration   2
#
# FOOLING RATE:  0.5619
# Iteration   3
#
# FOOLING RATE:  0.5973
# Iteration   4
#
# FOOLING RATE:  0.6149
# Iteration   5
#
# FOOLING RATE:  0.6323
# Iteration   6
#
# FOOLING RATE:  0.6474
# Iteration   7
#
# FOOLING RATE:  0.6585
# Iteration   8
#
# FOOLING RATE:  0.6654
# Iteration   9
#
# FOOLING RATE:  0.6742
# Iteration   10
#
# FOOLING RATE:  0.68
# Iteration   11
#
# FOOLING RATE:  0.6838
# Iteration   12
#
# FOOLING RATE:  0.6868
# Iteration   13
#
# FOOLING RATE:  0.6932
# Iteration   14
#
# FOOLING RATE:  0.6968
# Iteration   15
#
# FOOLING RATE:  0.7006
# Iteration   16
#
# FOOLING RATE:  0.7036
# Iteration   17
#
# FOOLING RATE:  0.707
# Iteration   18
#
# FOOLING RATE:  0.7089
# Iteration   19
#
# FOOLING RATE:  0.7109
# Iteration   20
#
# FOOLING RATE:  0.7123
# Iteration   21
#
# FOOLING RATE:  0.714
# Iteration   22
#
# FOOLING RATE:  0.7151
# Iteration   23
#
# FOOLING RATE:  0.7166
# Iteration   24
#
# FOOLING RATE:  0.7178
# Iteration   25
#
# FOOLING RATE:  0.7191
# Iteration   26
#
# FOOLING RATE:  0.7198
# Iteration   27
#
# FOOLING RATE:  0.72
# Iteration   28
#
# FOOLING RATE:  0.7202
# Iteration   29
#
# FOOLING RATE:  0.7205
# Iteration   30
#
# FOOLING RATE:  0.7208
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.4393
# Iteration   2
#
# FOOLING RATE:  0.528
# Iteration   3
#
# FOOLING RATE:  0.5522
# Iteration   4
#
# FOOLING RATE:  0.5648
# Iteration   5
#
# FOOLING RATE:  0.5734
# Iteration   6
#
# FOOLING RATE:  0.5778
# Iteration   7
#
# FOOLING RATE:  0.5808
# Iteration   8
#
# FOOLING RATE:  0.5822
# Iteration   9
#
# FOOLING RATE:  0.5833
# Iteration   10
#
# FOOLING RATE:  0.585
# Iteration   11
#
# FOOLING RATE:  0.5858
# Iteration   12
#
# FOOLING RATE:  0.5861
# Iteration   13
#
# FOOLING RATE:  0.5867
# Iteration   14
#
# FOOLING RATE:  0.5869
# Iteration   15
#
# FOOLING RATE:  0.5879
# Iteration   16
#
# FOOLING RATE:  0.5882
# Iteration   17
#
# FOOLING RATE:  0.588
# Iteration   18
#
# FOOLING RATE:  0.5885
# Iteration   19
#
# FOOLING RATE:  0.5889
# Iteration   20
#
# FOOLING RATE:  0.5885
# Iteration   21
#
# FOOLING RATE:  0.5887
# Iteration   22
#
# FOOLING RATE:  0.5886
# Iteration   23
#
# FOOLING RATE:  0.5885
# Iteration   24
#
# FOOLING RATE:  0.5886
# Iteration   25
#
# FOOLING RATE:  0.5883
# Iteration   26
#
# FOOLING RATE:  0.5884
# Iteration   27
#
# FOOLING RATE:  0.5886
# Iteration   28
#
# FOOLING RATE:  0.5885
# Iteration   29
#
# FOOLING RATE:  0.5886
# Iteration   30
#
# FOOLING RATE:  0.5885
# Device: cuda:0
# Clean model accuracy: 99.18%
# Iteration   1
#
# FOOLING RATE:  0.5543
# Iteration   2
#
# FOOLING RATE:  0.6041
# Iteration   3
#
# FOOLING RATE:  0.6272
# Iteration   4
#
# FOOLING RATE:  0.6458
# Iteration   5
#
# FOOLING RATE:  0.6781
# Iteration   6
#
# FOOLING RATE:  0.6961
# Iteration   7
#
# FOOLING RATE:  0.704
# Iteration   8
#
# FOOLING RATE:  0.7117
# Iteration   9
#
# FOOLING RATE:  0.7202
# Iteration   10
#
# FOOLING RATE:  0.7227
# Iteration   11
#
# FOOLING RATE:  0.7279
# Iteration   12
#
# FOOLING RATE:  0.7312
# Iteration   13
#
# FOOLING RATE:  0.7336
# Iteration   14
#
# FOOLING RATE:  0.736
# Iteration   15
#
# FOOLING RATE:  0.7381
# Iteration   16
#
# FOOLING RATE:  0.7399
# Iteration   17
#
# FOOLING RATE:  0.7423
# Iteration   18
#
# FOOLING RATE:  0.7437
# Iteration   19
#
# FOOLING RATE:  0.7459
# Iteration   20
#
# FOOLING RATE:  0.7473
# Iteration   21
#
# FOOLING RATE:  0.7489
# Iteration   22
#
# FOOLING RATE:  0.7502
# Iteration   23
#
# FOOLING RATE:  0.7512
# Iteration   24
#
# FOOLING RATE:  0.7525
# Iteration   25
#
# FOOLING RATE:  0.7532
# Iteration   26
#
# FOOLING RATE:  0.7537
# Iteration   27
#
# FOOLING RATE:  0.754
# Iteration   28
#
# FOOLING RATE:  0.7541
# Iteration   29
#
# FOOLING RATE:  0.7545
# Iteration   30
#
# FOOLING RATE:  0.7551

# %%
# make plot correlating fooling rate and decisin boundary distance
x = ratios_svd[1:n_svds]
Y = fooling_rates_svd[1:]
r = np.zeros(len(l2_norms))

for i in range(len(l2_norms)):
    y = Y[:,i]

    r[i], _ = sp.stats.pearsonr(x,y)
plt.plot(l2_norms,r)
plt.xlabel('l2-length of perturbation')
plt.ylabel('person correlation coefficient')
plt.title('Correlation of fooling ratio and distance to decision boundary ratio')
plt.show()


idx=np.argwhere(l2_norms==6)
plt.scatter(x,Y[:,idx])
plt.xlabel('decision boundary distance ratio')
plt.ylabel('fooling ratios')
plt.title('l2-length 6, correlation coefficient = %.2f' % (r[idx]))
plt.show()

# %%
plt.plot(l2_norms,fooling_rates_universal,'k--', linewidth=3)
for i, fr in enumerate(fooling_rates_svd):
    if i ==0:
        continue
    relative_ratio = (ratios_svd[i]-ratios_svd[1:n_svds].min())/(ratios_svd[1:n_svds].max()-ratios_svd[1:n_svds].min())
    color = np.clip(np.array([2*relative_ratio,2*(1-relative_ratio),0]),0,0.8)
    plt.plot(l2_norms, fr, c=color)
plt.xlabel('l2-length of perturbation')
plt.ylabel('fooling rate')

# %%
# ratio of universal perturbations
d_uni = np.zeros((n_images,len(universal_perts)))

for i, img in enumerate(images[img_indices]):
    for j, u in enumerate(universal_perts):
        d_uni[i,j] = get_dist(img, u, model_natural)
    print('%.2f%% done!' % ((i+1)/n_images*100))
ratios = np.nanmean(d_uni/d_random.reshape(-1,1), axis=0)
print(ratios)
np.nanmean(ratios)

# %% [markdown]
# # Check orthogonality of Tramer et al.

# %%
img_n =0
image = images[img_n:img_n+1]

label = torch.autograd.Variable(torch.tensor(labels[img_n:img_n+1], device=dev()))
adv = advs[img_n:img_n+1,0].reshape(image.shape)

loss = torch.nn.CrossEntropyLoss()

preds_correct = model_natural(torch.tensor(image, device=dev()))
preds_adv = model_natural(torch.tensor(adv, device=dev()))

loss_correct = loss(preds_correct, label)
loss_adv = loss(preds_adv,label)

change_in_loss_desired = loss_adv - loss_correct

epsilon = 3
g = dirs[img_n,0]
Q = subspace_utils.random_rotation_matrix(g)

for n_attack in np.arange(1,20):
    
    grad_coeff = 1/np.sqrt(n_attack+0.1)
    new_perts = subspace_utils.ortho_attack(Q, g, grad_coeff)
    for i, pert in enumerate(new_perts):
        adv = image + (epsilon*pert).reshape(image.shape)
        preds_adv = model_natural(torch.tensor(adv.astype(np.float32),device=dev()))
        loss_adv = loss(preds_adv,label)
        change_in_loss = loss_adv - loss_correct

        if change_in_loss<change_in_loss_desired:
            print('Maximum num attacks = ' + str(n_attack-1))
            break
    else:
        perts = new_perts
        continue
    break
print('Found dimensions:' + str(len(perts)))
    
plt.imshow(np.dot(perts,perts.T))
plt.show()

perts_clipped = (image.flatten()+perts).clip(0,1)-image.flatten()
perts_clipped= perts_clipped/np.linalg.norm(perts_clipped,axis=-1).reshape((-1,1))

plt.imshow(np.dot(perts_clipped,perts_clipped.T),vmin=0)
plt.show()
u,s,v=np.linalg.svd(perts_clipped)#-np.mean(perts_clipped,axis=0))
# Out:
# Maximum num attacks = 5
# Found dimensions:5

# %%
img_n = 1
p_clipped=dirs[img_n]+np.clip(advs[img_n],0,1)-advs[img_n]
u,s,v=np.linalg.svd(perts_clipped)#-np.mean(perts_clipped,axis=0))
plt.scatter(range(len(s)),s)
plt.xlabel('n')
plt.ylabel('eigenvalue')
plt.show()
