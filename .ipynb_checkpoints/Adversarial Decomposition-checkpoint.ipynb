# %%
import matplotlib.pyplot as plt
import numpy as np
import plots as pl
import dec_space
from models import model, eval
import torch
from utils import dev
from torchvision import datasets, transforms
from models import eval
from sklearn import decomposition

# %matplotlib inline

# %% [markdown]
# # Universal Advs

# %%
# define funstions

def get_dist(orig, pert, model, delta=0.01, epsilons = np.linspace(-100,100,201)):
    orig = orig.reshape(784)
    unitary_pert = pert.reshape(784)/np.linalg.norm(pert.reshape(784))
    
    label = np.argmax(model(torch.tensor(np.reshape(orig, (1, 1, 28, 28)))).detach().cpu().numpy())
    
    inputs = np.outer(epsilons,unitary_pert) + orig
    proj_inputs = np.clip(inputs,0,1)
    pred = model(torch.tensor(proj_inputs.astype('float32')).reshape(-1, 1, 28, 28)).detach().cpu().numpy()
    pred_classes = np.argmax(pred, axis=-1)

    if np.all(pred_classes==label):
        return np.nan
    
    changed = epsilons[pred_classes != label]
    min_epsilon_idx = np.argmin(abs(changed))
    idx = np.argwhere(epsilons==changed[min_epsilon_idx])

    
    # do a second search with more precise epsilon
    if epsilons[idx]>0:
        new_epsilons = np.linspace(epsilons[idx-1], epsilons[idx], np.maximum(int(1/delta),100))
    else: 
        new_epsilons = np.linspace(epsilons[idx+1], epsilons[idx], np.maximum(int(1/delta),100))
        
    inputs = np.outer(new_epsilons, unitary_pert) + orig
    proj_inputs = np.clip(inputs,0,1)
    
    pred = model(torch.tensor(proj_inputs.astype('float32')).reshape(-1, 1, 28, 28)).detach().cpu().numpy()
    pred_classes = np.argmax(pred, axis=-1)
    
    idx = np.min(np.argwhere(pred_classes != label))
        
    return np.linalg.norm(proj_inputs[idx]-orig)
    

def get_mean_dist(orig, model, n_sample_dirs=100, delta=0.01):
    dists = np.zeros(n_sample_dirs)
        
    # generate n random unitary vectors
    dirs = np.random.uniform(size=(n_sample_dirs,784)) - orig.reshape(784)
    
    for i, d in enumerate(dirs):
        dists[i] = get_dist(orig, d, model, delta, epsilons = np.linspace(0,100,101))
        
    mean_dist = np.nanmean(dists)
    
    return mean_dist

# %% [markdown]
# ## Load data and models

# %%
# load data
data = np.load('data/cnn5.npy', allow_pickle=True).item()
advs = data['advs']
pert_lengths = data['pert_lengths']
classes = data['adv_class']
dirs = data['dirs']
images = data['images']
labels = data['labels']

# %%
# load models
model_natural = model.madry()
model_madry = model.madry()
model_natural.load_state_dict(torch.load('./models/natural.pt', map_location=torch.device(dev())))
model_madry.load_state_dict(torch.load('./models/adv_trained_l2.pt', map_location=torch.device(dev())))
# Out:
# /home/lu/.local/lib/python3.8/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0
# <All keys matched successfully>

# %%
# extract singular values and vectors
M = dirs[:,0].reshape(-1,dirs[:,0].shape[-1])
u,s,v = np.linalg.svd(M)

# visualize first 10 singular vectors
plt.subplots(2,5,figsize=(15,5))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(v[i].reshape((28,28)))
    plt.xticks([])
    plt.yticks([])
    plt.title('SV' + str(i+1))

# %% [markdown]
# ## Check how many random perturbation samples are needed for good estimate

# %%
# see when random length converges
n_runs = 40
n_samples = np.logspace(3,4,n_runs)
e_random = np.zeros(n_runs)
for i,n in enumerate(n_samples):
    e_random[i] = get_mean_dist(images[0], model_natural, int(n))
plt.plot(np.log10(n_samples),e_random)

# %% [markdown]
# ## Get ratios for siingular vectors and random directions

# %%
n_images = 20
n_singular_vectors = 784
d_svd = np.zeros((n_images, n_singular_vectors))
d_random = np.zeros(n_images)

img_indices = np.random.shuffle(np.arange(len(images)))[:n_images]

for i, img in enumerate(images[img_indices]):
    d_random[i] = get_mean_dist(img, model_natural, n_sample_dirs=200)
    for j in range(n_singular_vectors):
        d_svd[i,j] = get_dist(img, v[j], model_natural)
    print(str((i+1)/n_images*100) + '% done!' )
# Out:
# 5.0% done!
# 10.0% done!
# 15.0% done!
# 20.0% done!
# 25.0% done!
# 30.0% done!
# 35.0% done!
# 40.0% done!
# 45.0% done!
# 50.0% done!
# 55.00000000000001% done!
# 60.0% done!
# 65.0% done!
# 70.0% done!
# 75.0% done!
# 80.0% done!
# 85.0% done!
# 90.0% done!
# 95.0% done!
# 100.0% done!

# %%
ratios = np.nanmean(d_svd /d_random.reshape(-1,1),axis=0)
plt.figure(figsize=(8,5))
plt.plot(np.arange(1,d_svd.shape[1]+1),ratios)
plt.xlabel('n-th singular vector')
plt.ylabel('l2 distance ratio')
# plt.xticks(np.arange(1,d_svd.shape[1]+1,d_svd.shape[1]/10))
plt.title('Ratio of random and singular vector l2 distance to decsion boundary')
np.nanmean(d_random)
# Out:
# 10.297711797703482

# %% [markdown]
# ## Get ratios of random perturbations and principal adversarial directions

# %%
# ratio of principle adversarials
n_images = 20

d_random = np.zeros(n_images)
dists=np.zeros((n_images,5))
img_indices = np.random.shuffle(np.arange(len(images)))[:n_images]

for i, img in enumerate(images[img_indices]):
    d_random[i] = get_mean_dist(img, model_natural, n_sample_dirs=200)
    for j,d in enumerate(dirs[i]):
        dists[i,j] = get_dist(img, dirs[i,j], model_natural)
    print(str((i+1)/n_images*100) + '% done!' )
# Out:
# 5.0% done!
# 10.0% done!
# 15.0% done!
# 20.0% done!
# 25.0% done!
# 30.0% done!
# 35.0% done!
# 40.0% done!
# 45.0% done!
# 50.0% done!
# 55.00000000000001% done!
# 60.0% done!
# 65.0% done!
# 70.0% done!
# 75.0% done!
# 80.0% done!
# 85.0% done!
# 90.0% done!
# 95.0% done!
# 100.0% done!
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-8adf6bc398df> in <module>
#       6
#       7 for i, img in enumerate(images):
# ----> 8     d_random[i] = get_mean_dist(img, model_natural, n_sample_dirs=200)
#       9     for j,d in enumerate(dirs[i]):
#      10         dists[i,j] = get_dist(img, dirs[i,j], model_natural)
#
# IndexError: index 20 is out of bounds for axis 0 with size 20

# %%
ratios = np.nanmean(dists /d_random.reshape(-1,1),axis=0)
plt.figure(figsize=(8,5))
plt.plot(np.arange(1,dists.shape[1]+1),ratios)
plt.xlabel('n-th principal adversarial direction')
plt.ylabel('l2 distance ratio')
# plt.xticks(np.arange(1,d_svd.shape[1]+1,d_svd.shape[1]/10))
plt.title('Ratio of random and principal adversarial direction l2 distance to decsion boundary')
np.nanmean(d_random)
# Out:
# 10.970822324621137

# %% [markdown]
# ## Extract universal directions via code from https://paperswithcode.com/paper/universal-adversarial-perturbations

# %%
from UniversalPerturbations import adversarial_perturbation
import torch
from torchvision import datasets, transforms

trainset = torch.utils.data.DataLoader(
    datasets.MNIST('./data', train=True, download=True,
                   transform=transforms.ToTensor()),
    batch_size=32, shuffle=True)

testset = torch.utils.data.DataLoader(
    datasets.MNIST('./data', train=False,
                   transform=transforms.ToTensor()),
    batch_size=5)

net = model_natural

universal_pert, fooling_rates, accuracies, total_iterations=adversarial_perturbation.generate(trainset, testset, net, p=2, xi=10, max_iter_uni=30)

plt.title("Fooling Rates over Universal Iterations")
plt.xlabel("Universal Algorithm Iter")
plt.ylabel("Fooling Rate on test data")
plt.plot(total_iterations,fooling_rates)
plt.show()


plt.title("Accuracy over Universal Iterations")
plt.xlabel("Universal Algorithm Iter")
plt.ylabel("Accuracy on Test data")
plt.plot(total_iterations, accuracies)
plt.show()
# Out:
# Clean model accuracy: 99.18%
# Iteration   0
#
# FOOLING RATE:  0.0019
# Iteration   1
#
# FOOLING RATE:  0.0019
# Iteration   2
#
# FOOLING RATE:  0.0022
# Iteration   3
#
# FOOLING RATE:  0.0017
# Iteration   4
#
# FOOLING RATE:  0.0017
# Iteration   5
#
# FOOLING RATE:  0.0017
# Iteration   6
#
# FOOLING RATE:  0.0018
# Iteration   7
#
# FOOLING RATE:  0.002
# Iteration   8
#
# FOOLING RATE:  0.0018
# Iteration   9
#
# FOOLING RATE:  0.0017
# Iteration   10
#
# FOOLING RATE:  0.0018
# Iteration   11
#
# FOOLING RATE:  0.0019
# Iteration   12
#
# FOOLING RATE:  0.0016
# Iteration   13
#
# FOOLING RATE:  0.0018
# Iteration   14
#
# FOOLING RATE:  0.0017
# Iteration   15
#
# FOOLING RATE:  0.0018
# Iteration   16
#
# FOOLING RATE:  0.0017
# Iteration   17
#
# FOOLING RATE:  0.0018
# Iteration   18
#
# FOOLING RATE:  0.002
# Iteration   19

# %%
plt.imshow(universal_pert)
plt.colorbar()

proj_inputs = np.clip(images + universal_pert, 0, 1)
pred = model_natural(torch.tensor(proj_inputs.astype('float32')).reshape(-1, 1, 28, 28)).detach().cpu().numpy()
new_labels = np.argmax(pred, axis=-1)
fooling_rate = (new_labels != labels).sum()/len(labels)
fooling_rate

# %%
np.linalg.norm(universal_pert)
# Out:
# 7.6335309513999166

# %%
# ratio of principle adversarials
n_images = 20


img_indices = np.arange(len(images))
np.random.shuffle(img_indices)
img_indices=img_indices[:n_images]
dists = np.zeros(n_images)
d_random =np.zeros(n_images)

for i, img in enumerate(images[img_indices]):
    d_random[i] = get_mean_dist(img, model_natural, n_sample_dirs=200)
    dists[i] = get_dist(img, universal_pert, model_natural)
    print('%.2f%% done!' % ((i+1)/n_images*100))
ratio = np.nanmean(dists/d_random)
ratio
# Out:
# 5.0% done!
# 10.0% done!
# 15.0% done!
# 20.0% done!
# 25.0% done!
# 30.0% done!
# 35.0% done!
# 40.0% done!
# 45.0% done!
# 50.0% done!
# 55.00000000000001% done!
# 60.0% done!
# 65.0% done!
# 70.0% done!
# 75.0% done!
# 80.0% done!
# 85.0% done!
# 90.0% done!
# 95.0% done!
# 100.0% done!
# 0.5483515641967187
